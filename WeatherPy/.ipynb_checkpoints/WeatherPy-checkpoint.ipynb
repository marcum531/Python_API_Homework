# %%
#The data shows that there is an expected relationship between temperature and latitude.  The closer to the equator 
#latitude (0) the hotter the temperature.  There does not seem to be a relationship between humidity, cloudiness, or wind speed
#and latitude in the Northern Hemisphere.  There does seem to be a relationship between humidity and latitude in the 
#Southern Hemisphere, but not much of a relationship between cloudiness or wind speed and latitude in the Southern Hemisphere.

# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# %%
# api key for OpenWeatherMap
api_key = '0ef0e1e8cae0c9ce2fd55f511fb39ea6'

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = 'Imperial'
query_url = f"{url}appid={api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=0ef0e1e8cae0c9ce2fd55f511fb39ea6&units=Imperial&q='

# %%
temp = []
lat = []
lon = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

for city in cities:
    weather_response = requests.get(query_url + city).json()
    
    try:
        temp.append(weather_response["main"]['temp'])
        lat.append(weather_response['coord']['lat'])
        lon.append(weather_response['coord']['lon'])
        humidity.append(weather_response['main']['humidity'])
        cloudiness.append(weather_response['clouds']['all'])
        wind_speed.append(weather_response['wind']['speed'])
        country.append(weather_response['sys']['country'])
        date.append(weather_response['dt'])
        print("Retrieved data for %s" % (weather_response['name']))
    except (KeyError, IndexError):
        print("No city found. Skipping....")
# Out:
# Retrieved data for Busselton
# Retrieved data for Mataura
# Retrieved data for Yulara
# Retrieved data for Punta Arenas
# Retrieved data for Ribeira Grande
# Retrieved data for Ushuaia
# Retrieved data for Saskylakh
# Retrieved data for Hilo
# Retrieved data for Butaritari
# Retrieved data for Rikitea
# Retrieved data for Upernavik
# No city found. Skipping....
# Retrieved data for Albany
# Retrieved data for Takoradze
# Retrieved data for Bengkulu
# Retrieved data for San Cristobal
# No city found. Skipping....
# Retrieved data for Salalah
# Retrieved data for Sovetskiy
# Retrieved data for Lebu
# Retrieved data for Pevek
# Retrieved data for Chokurdakh
# Retrieved data for Dikson
# Retrieved data for Lodwar
# Retrieved data for Trairi
# Retrieved data for Norman Wells
# No city found. Skipping....
# Retrieved data for East London
# Retrieved data for Qaanaaq
# Retrieved data for Sennar
# Retrieved data for Bredasdorp
# Retrieved data for Morros
# Retrieved data for Brae
# Retrieved data for Xinzhi
# Retrieved data for Nanortalik
# No city found. Skipping....
# Retrieved data for Kushima
# Retrieved data for Lenine
# No city found. Skipping....
# Retrieved data for Zhigansk
# No city found. Skipping....
# Retrieved data for Marsaxlokk
# Retrieved data for Tuktoyaktuk
# Retrieved data for Srednekolymsk
# Retrieved data for Port Alfred
# Retrieved data for Atasū
# Retrieved data for Castro
# Retrieved data for Hokitika
# Retrieved data for Roald
# Retrieved data for Tarko-Sale
# Retrieved data for Sibolga
# No city found. Skipping....
# Retrieved data for Karaton
# Retrieved data for Nikolskoye
# No city found. Skipping....
# Retrieved data for Innisfail
# Retrieved data for Thompson
# Retrieved data for Igarka
# Retrieved data for Provideniya
# Retrieved data for Geraldton
# Retrieved data for Wajir
# Retrieved data for Suntar
# Retrieved data for Pangnirtung
# Retrieved data for Codrington
# Retrieved data for Gbadolite
# No city found. Skipping....
# No city found. Skipping....
# Retrieved data for
# Retrieved data for Necochea
# Retrieved data for Lac-Mégantic
# Retrieved data for Knysna
# Retrieved data for Hamilton
# Retrieved data for Nueve de Julio
# Retrieved data for Tsimmerbude
# Retrieved data for Waipawa
# No city found. Skipping....
# Retrieved data for Tooele
# Retrieved data for Freeport
# Retrieved data for Tangi
# Retrieved data for Boyolangu
# Retrieved data for Sikasso
# Retrieved data for Katangli
# Retrieved data for Buala
# Retrieved data for Comodoro Rivadavia
# Retrieved data for Fortuna
# Retrieved data for Port Lincoln
# Retrieved data for Aquin
# Retrieved data for Demidov
# Retrieved data for Soyo
# Retrieved data for Yenagoa
# Retrieved data for West Bay
# Retrieved data for Zambezi
# Retrieved data for Kosh-Agach
# Retrieved data for Powell River
# Retrieved data for Yeppoon
# Retrieved data for San Matías
# Retrieved data for Wangqing
# Retrieved data for Svetlaya
# Retrieved data for Lüshunkou
# Retrieved data for Sur
# Retrieved data for Metro
# Retrieved data for Torbay
# Retrieved data for Katiola
# Retrieved data for Ha Tinh
# Retrieved data for Gigmoto
# Retrieved data for Xambioá
# Retrieved data for Hājīganj
# No city found. Skipping....
# Retrieved data for Kysyl-Syr
# Retrieved data for Kachug
# Retrieved data for Gazalkent
# Retrieved data for São José da Coroa Grande
# Retrieved data for Chingirlau
# Retrieved data for Morehead
# Retrieved data for Pemangkat
# Retrieved data for Atherton
# Retrieved data for Zheleznodorozhnyy
# Retrieved data for São Filipe
# No city found. Skipping....
# Retrieved data for Pak Phanang
# Retrieved data for Deputatsky
# Retrieved data for Baghmara
# Retrieved data for Cavalcante
# Retrieved data for Palmas de Monte Alto
# Retrieved data for Ancud
# Retrieved data for Opelousas
# Retrieved data for Bria
# Retrieved data for Aasiaat
# Retrieved data for Kavaratti
# Retrieved data for Dudinka
# Retrieved data for Vanavara
# Retrieved data for Kampene
# Retrieved data for Sinop Province
# Retrieved data for Bukachacha
# Retrieved data for Lixouri
# Retrieved data for Buriti Bravo
# Retrieved data for Catuday
# Retrieved data for Opalenica
# Retrieved data for Namatanai
# Retrieved data for Kruisfontein
# Retrieved data for Charters Towers
# Retrieved data for Ordzhonīkīdze
# Retrieved data for Coelho Neto
# Retrieved data for Dongsheng
# Retrieved data for Walvis Bay
# Retrieved data for Raudeberg
# Retrieved data for Marzuq
# Retrieved data for Tiznit Province
# Retrieved data for Vereshchagino
# Retrieved data for Basco
# Retrieved data for Buluang
# Retrieved data for Alugan
# Retrieved data for Maturin
# Retrieved data for Kushiro
# Retrieved data for Nabire
# Retrieved data for Lewistown
# Retrieved data for Sambava
# Retrieved data for Kununurra
# No city found. Skipping....
# Retrieved data for Kremenchuk
# Retrieved data for Hohhot
# Retrieved data for Antsohihy
# Retrieved data for Tigil'
# Retrieved data for Labuhan
# Retrieved data for Fare
# Retrieved data for Zhangye
# Retrieved data for Yerbogachën
# Retrieved data for Bambous Virieux
# Retrieved data for Ko Samui
# Retrieved data for Clarence Town
# Retrieved data for Verāval
# Retrieved data for Saint-Joseph
# Retrieved data for Lázaro Cárdenas
# Retrieved data for Vila
# Retrieved data for Nsoko
# Retrieved data for Culaman
# Retrieved data for Sitka
# Retrieved data for Koungou
# Retrieved data for Tutóia
# Retrieved data for Laguna
# Retrieved data for Padampur
# Retrieved data for Port-Gentil
# Retrieved data for Petropavlovsk-Kamchatskiy
# Retrieved data for Saint George
# Retrieved data for Doha
# Retrieved data for Khasan
# Retrieved data for Antalaha
# Retrieved data for Okhotsk
# Retrieved data for Villa Rica
# Retrieved data for Solnechnyy
# Retrieved data for Xining
# Retrieved data for Flin Flon
# Retrieved data for Koster
# Retrieved data for Skegness
# Retrieved data for Mossamedes
# Retrieved data for Karratha
# Retrieved data for Goubellat
# Retrieved data for Bahía Blanca
# Retrieved data for Ilhabela
# No city found. Skipping....
# Retrieved data for Majene
# Retrieved data for Sisimiut
# Retrieved data for Barra do Garças
# Retrieved data for Lethem
# Retrieved data for Río Gallegos
# Retrieved data for Lorengau
# Retrieved data for Pulaski
# No city found. Skipping....
# Retrieved data for Rizhao
# Retrieved data for Ust-Tsilma
# Retrieved data for Mackay
# Retrieved data for Itanagar
# Retrieved data for North Bend
# Retrieved data for Eyl
# Retrieved data for Umm Kaddadah
# Retrieved data for Loíza
# Retrieved data for Fort Walton Beach
# Retrieved data for Palmas
# Retrieved data for Gao
# Retrieved data for Achalpur
# Retrieved data for Indian Head
# Retrieved data for Northam
# Retrieved data for Batemans Bay
# Retrieved data for Buchanan
# Retrieved data for Rocha
# Retrieved data for Agua Prieta
# Retrieved data for Sistranda
# Retrieved data for Acapulco de Juárez
# Retrieved data for Hambantota
# No city found. Skipping....
# No city found. Skipping....
# Retrieved data for Safford
# No city found. Skipping....
# Retrieved data for Koutiala
# Retrieved data for Priladozhskiy
# No city found. Skipping....
# Retrieved data for Sioux Lookout
# Retrieved data for Vágur
# Retrieved data for Acaraú
# Retrieved data for Soe
# Retrieved data for Marrakesh
# Retrieved data for Isabela
# Retrieved data for Kawalu
# No city found. Skipping....
# Retrieved data for Caruray
# Retrieved data for Nehe
# Retrieved data for Gamba
# Retrieved data for Lubao
# Retrieved data for Chebsara
# Retrieved data for Bantou
# Retrieved data for Paragominas
# Retrieved data for Bom Jesus
# No city found. Skipping....
# No city found. Skipping....
# Retrieved data for Ciudad de Armería
# Retrieved data for Marabu
# Retrieved data for Suez
# Retrieved data for Rena
# Retrieved data for Ferry Pass
# Retrieved data for Alihe
# Retrieved data for Wajima
# Retrieved data for Nereju
# Retrieved data for Tabou
# Retrieved data for Horsham
# Retrieved data for Abu Kamal
# Retrieved data for Sangīn
# No city found. Skipping....
# Retrieved data for Nemuro
# Retrieved data for Berzence
# Retrieved data for Najrān
# Retrieved data for Pochutla
# Retrieved data for Sabang
# Retrieved data for San Patricio

# %%
plt.scatter(lat, temp, marker='o', facecolors='blue', edgecolors='black', alpha=0.75)
plt.title("Temperature (F) vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel("Temperature (F)")
plt.show()
#This scatterplot shows a strong relationship between temperature and latitude.

# %%
plt.scatter(lat, humidity, marker='o', facecolors='blue', edgecolors='black', alpha=0.75)
plt.title("Humidity (%) vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel("Humidity (%)")
plt.show()
#This scatterplot shows a weak relationship between humidity and latitude.

# %%
plt.scatter(lat, cloudiness, marker='o', facecolors='blue', edgecolors='black', alpha=0.75)
plt.title("Cloudiness (%) vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel("Cloudiness (%)")
plt.show()
#This scatterplot shows a weak relationship between cloudiness and latitude.

# %%
plt.scatter(lat, wind_speed, marker='o', facecolors='blue', edgecolors='black', alpha=0.75)
plt.title("Wind Speed (mph) vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel("Wind Speed (mph)")
plt.show()
#The scatterplot shows a weak relationship between the wind speed and latitude.

# %%
weather_df = pd.DataFrame(
    {"City":pd.Series(cities),
    "Temp":pd.Series(temp),
    "Latitude":pd.Series(lat),
     "Longitude":pd.Series(lon),
    "Humidity":pd.Series(humidity),
    "Cloudiness":pd.Series(cloudiness),
    "Wind Speed":pd.Series(wind_speed),
    "Country":pd.Series(country),
    "Date":pd.Series(date)})
weather_df.head()
# Out:
#              City   Temp  Latitude  Longitude  Humidity  Cloudiness  \
# 0       busselton  58.41    -33.65     115.33      55.0        84.0
# 1         mataura  47.46    -46.19     168.86      90.0       100.0
# 2          yulara  51.80    -25.24     130.99      34.0         0.0
# 3    punta arenas  33.39    -53.15     -70.92      79.0        62.0
# 4  ribeira grande  64.83     38.52     -28.70      90.0        11.0
#
#    Wind Speed Country          Date
# 0       27.22      AU  1.592353e+09
# 1        8.99      NZ  1.592353e+09
# 2       11.41      AU  1.592353e+09
# 3        5.82      CL  1.592353e+09
# 4       17.00      PT  1.592353e+09

# %%
weather_df['Humidity'].max()
# Out:
# 100.0

# %%
weather_df.describe()
# Out:
#              Temp    Latitude   Longitude    Humidity  Cloudiness  Wind Speed  \
# count  560.000000  560.000000  560.000000  560.000000  560.000000  560.000000
# mean    67.746821   20.042018   21.325446   70.183929   47.723214    8.085000
# std     13.851585   33.170888   89.428206   21.251794   37.077931    5.309837
# min     30.200000  -54.800000 -175.200000    3.000000    0.000000    0.160000
# 25%     57.215000   -5.912500  -56.105000   57.000000   10.000000    3.970000
# 50%     69.530000   20.915000   24.700000   75.000000   40.000000    6.930000
# 75%     78.800000   48.922500  105.885000   86.000000   83.000000   11.180000
# max    100.400000   78.220000  179.320000  100.000000  100.000000   27.290000
#
#                Date
# count  5.600000e+02
# mean   1.592353e+09
# std    5.121853e+01
# min    1.592353e+09
# 25%    1.592353e+09
# 50%    1.592353e+09
# 75%    1.592354e+09
# max    1.592354e+09

# %%
weather_df.to_csv('weatherpy_data.csv', encoding='utf-8', index=False)

# %%
weather_north = weather_df.loc[weather_df["Latitude"] >=0]
weather_north
# Out:
#                City   Temp  Latitude  Longitude  Humidity  Cloudiness  \
# 4    ribeira grande  64.83     38.52     -28.70      90.0        11.0
# 6         saskylakh  61.16     71.92     114.08      37.0         3.0
# 7              hilo  73.18     19.73    -155.09      73.0        90.0
# 8        butaritari  82.92      3.07     172.79      80.0         2.0
# 10        upernavik  32.07     72.79     -56.15      94.0        76.0
# ..              ...    ...       ...        ...       ...         ...
# 555          rizhao  62.87     46.21      17.15      88.0        75.0
# 556      ust-tsilma  77.00     17.49      44.13      23.0        61.0
# 557          mackay  87.80     15.74     -96.47      62.0        75.0
# 558        itanagar  83.23      5.89      95.32      67.0       100.0
# 559      north bend  82.40     19.22    -104.70      78.0        40.0
#
#      Wind Speed Country          Date
# 4         17.00      PT  1.592353e+09
# 6         20.87      RU  1.592353e+09
# 7         10.29      US  1.592353e+09
# 8         11.54      KI  1.592353e+09
# 10         3.91      GL  1.592353e+09
# ..          ...     ...           ...
# 555        8.05      HU  1.592354e+09
# 556        2.73      SA  1.592354e+09
# 557        6.93      MX  1.592354e+09
# 558        6.13      ID  1.592354e+09
# 559       17.22      MX  1.592354e+09
#
# [387 rows x 9 columns]

# %%
x_axis = weather_north['Latitude'].values
y_axis = weather_north['Temp'].values

# %%
plt.scatter(x_axis, y_axis, marker='o', facecolors='blue', edgecolors='black', alpha=0.75, label='original data')
plt.title("Temperature (F) vs. Latitude in the Northern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel("Temperature (F)")
slope, intercept, r_value, p_value, std_err = linregress(x_axis, y_axis)
print(f'y= {slope}x + {intercept}.')
print(f'The r-squared value is {r_value}.')
plt.plot(x_axis, intercept + slope*x_axis, "r", label='fitted label')
plt.legend()
plt.show()
#This scatterplot show a strong relationship between Temperature and Latitude.
# Out:
# y= -0.524149268060857x + 88.69613477163178.
# The r-squared value is -0.7521523329402819.

# %%
x_axis1 = weather_north['Latitude'].values
y_axis1 = weather_north['Humidity'].values

# %%
plt.scatter(x_axis1, y_axis1, marker='o', facecolors='blue', edgecolors='black', alpha=0.75, label='original data')
plt.title("Humidity (%) vs. Latitude in the Northern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel("Humidity (%)")
slope, intercept, r_value, p_value, std_err = linregress(x_axis1, y_axis1)
print(f'y= {slope}x + {intercept}.')
print(f'The r-squared value is {r_value}.')
plt.plot(x_axis1, intercept + slope*x_axis1, "r", label='fitted label')
plt.legend()
plt.show()
#This scatterplot shows a weak relationship between the Latitude and Humidity.
# Out:
# y= -0.03484737159445823x + 69.29503440451352.
# The r-squared value is -0.03220058662768179.

# %%
x_axis2 = weather_north['Latitude'].values
y_axis2 = weather_north['Cloudiness'].values

# %%
plt.scatter(x_axis2, y_axis2, marker='o', facecolors='blue', edgecolors='black', alpha=0.75, label='original data')
plt.title("Cloudiness (%) vs. Latitude in the Northern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel("Cloudiness (%)")
slope, intercept, r_value, p_value, std_err = linregress(x_axis2, y_axis2)
print(f'y= {slope}x + {intercept}.')
print(f'The r-squared value is {r_value}.')
plt.plot(x_axis2, intercept + slope*x_axis2, "r", label='fitted label')
plt.legend()
plt.show()
#This scatterplot shows a weak relationship between the Latitude and Cloudiness.
# Out:
# y= -0.0808219545029632x + 51.75157532836856.
# The r-squared value is -0.04576281904011575.

# %%
x_axis3 = weather_north['Latitude'].values
y_axis3 = weather_north['Wind Speed'].values

# %%
plt.scatter(x_axis3, y_axis3, marker='o', facecolors='blue', edgecolors='black', alpha=0.75, label='original data')
plt.title("Wind Speed (mph) vs. Latitude in the Northern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel("Wind Speed (mph)")
slope, intercept, r_value, p_value, std_err = linregress(x_axis3, y_axis3)
print(f'y= {slope}x + {intercept}.')
print(f'The r-squared value is {r_value}.')
plt.plot(x_axis3, intercept + slope*x_axis3, "r", label='fitted label')
plt.legend()
plt.show()
#This scatterplot shows a weak relationship between Wind Speed and Latitude.
# Out:
# y= 0.007396353466787196x + 7.6163137462533275.
# The r-squared value is 0.02976164324133878.

# %%
weather_south = weather_df.loc[weather_df["Latitude"] < 0]
weather_south
# Out:
#              City   Temp  Latitude  Longitude  Humidity  Cloudiness  \
# 0       busselton  58.41    -33.65     115.33      55.0        84.0
# 1         mataura  47.46    -46.19     168.86      90.0       100.0
# 2          yulara  51.80    -25.24     130.99      34.0         0.0
# 3    punta arenas  33.39    -53.15     -70.92      79.0        62.0
# 5         ushuaia  37.40    -54.80     -68.30      86.0        75.0
# ..            ...    ...       ...        ...       ...         ...
# 530  saint george  70.47     -9.86     124.28      85.0        71.0
# 533      antalaha  73.49     -7.38     108.21      91.0        81.0
# 536    solnechnyy  73.11     -2.65      10.00      92.0       100.0
# 540      skegness  75.22     -2.97     -47.48      80.0        17.0
# 541        namibe  77.43     -9.07     -44.36      59.0        94.0
#
#      Wind Speed Country          Date
# 0         27.22      AU  1.592353e+09
# 1          8.99      NZ  1.592353e+09
# 2         11.41      AU  1.592353e+09
# 3          5.82      CL  1.592353e+09
# 5         21.92      AR  1.592353e+09
# ..          ...     ...           ...
# 530        8.32      ID  1.592354e+09
# 533        0.25      ID  1.592354e+09
# 536        5.19      GA  1.592354e+09
# 540        4.16      BR  1.592353e+09
# 541        3.18      BR  1.592354e+09
#
# [173 rows x 9 columns]

# %%
y_axis4 = weather_south['Latitude'].values
x_axis4 = weather_south['Temp'].values

# %%
plt.scatter(x_axis4, y_axis4, marker='o', facecolors='blue', edgecolors='black', alpha=0.75, label='original data')
plt.title("Temperature (F) vs. Latitude in the Southern Hemisphere")
plt.xlabel('Temperaure(F)')
plt.ylabel("Latitude")
plt.xticks(np.arange(0, 100, step=10))
plt.yticks(np.arange(-60, 0, step=10))
slope, intercept, r_value, p_value, std_err = linregress(x_axis4, y_axis4)
print(f'y= {slope}x + {intercept}.')
print(f'The r-squared value is {r_value}.')
plt.plot(x_axis4, intercept + slope*x_axis4, "r", label='fitted label')
plt.legend()
plt.show()
#This scatterplot shows a strong relationship between Temperature and Latitude.
# Out:
# y= 0.9355673253510485x + -82.02318736693948.
# The r-squared value is 0.8019746956285295.

# %%
x_axis5 = weather_south['Humidity'].values
y_axis5 = weather_south['Latitude'].values

# %%
plt.scatter(x_axis5, y_axis5, marker='o', facecolors='blue', edgecolors='black', alpha=0.75, label='original data')
plt.title("Humidity (%) vs. Latitude in the Southern Hemisphere")
plt.xlabel('Humidity (%)')
plt.ylabel("Latitude")
plt.xticks(np.arange(0, 100, step=10))
plt.yticks(np.arange(-60, 0, step=10))
slope, intercept, r_value, p_value, std_err = linregress(x_axis5, y_axis5)
print(f'y= {slope}x + {intercept}.')
print(f'The r-squared value is {r_value}.')
plt.plot(x_axis5, intercept + slope*x_axis5, "r", label='fitted label')
plt.legend()
plt.show()
#This scatterplot shows a weak relationship between Humidity and Latitude.
# Out:
# y= -0.038424038103167045x + -17.692306824397257.
# The r-squared value is -0.046603797652663655.

# %%
x_axis6 = weather_south['Cloudiness'].values
y_axis6 = weather_south['Latitude'].values

# %%
plt.scatter(x_axis6, y_axis6, marker='o', facecolors='blue', edgecolors='black', alpha=0.75, label='original data')
plt.title("Cloudiness (%) vs. Latitude in the Southern Hemisphere")
plt.xlabel('Cloudiness (%)')
plt.ylabel("Latitude")
plt.xticks(np.arange(0, 100, step=10))
plt.yticks(np.arange(-60, 0, step=10))
slope, intercept, r_value, p_value, std_err = linregress(x_axis6, y_axis6)
print(f'y= {slope}x + {intercept}.')
print(f'The r-squared value is {r_value}.')
plt.plot(x_axis6, intercept + slope*x_axis6, "r", label='fitted label')
plt.legend()
plt.show()
#This scatterplot shows a weak relationship between Cloudiness and Latitude.
# Out:
# y= -0.042605201538585186x + -18.636299129812055.
# The r-squared value is -0.11550546773682949.

# %%
x_axis7 = weather_south["Wind Speed"].values
y_axis7 = weather_south['Latitude'].values

# %%
plt.scatter(x_axis7, y_axis7, marker='o', facecolors='blue', edgecolors='black', alpha=0.75, label='original data')
plt.title("Wind Speed (mph) vs. Latitude in the Southern Hemisphere")
plt.xlabel('Wind Speed (mph)')
plt.ylabel("Latitude")
plt.xticks(np.arange(0, 30, step=10))
plt.yticks(np.arange(-60, 0, step=10))
slope, intercept, r_value, p_value, std_err = linregress(x_axis7, y_axis7)
print(f'y= {slope}x + {intercept}.')
print(f'The r-squared value is {r_value}.')
plt.plot(x_axis7, intercept + slope*x_axis7, "r", label='fitted label')
plt.legend()
plt.show()
#This scatterplot shows a weak relationship between Wind Speed and Latitude.
# Out:
# y= -0.4035744203908142x + -17.148941947713375.
# The r-squared value is -0.16224249092084278.
